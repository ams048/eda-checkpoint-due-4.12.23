# %% [markdown]
# # Checkpoint Two: Exploratory Data Analysis
#
# Now that your chosen dataset is approved, it is time to start working on your analysis. Use this notebook to perform your EDA and make notes where directed to as you work.
#
# ## Getting Started
#
# Since we have not provided your dataset for you, you will need to load the necessary files in this repository. Make sure to include a link back to the original dataset here as well.
#
# My dataset:
#
# Your first task in EDA is to import necessary libraries and create a dataframe(s). Make note in the form of code comments of what your thought process is as you work on this setup task.

# %%
import pandas as pd

# Import eo_pr.csv
eo_pr = pd.read_csv('eo_pr.csv')

# Import eo_xx.csv
eo_xx = pd.read_csv('eo_xx.csv')

# Import eo1.csv
eo1 = pd.read_csv('eo1.csv')

# Import eo2.csv
eo2 = pd.read_csv('eo2.csv')

# Import eo3.csv
eo3 = pd.read_csv('eo3.csv')

# Import eo4.csv
eo4 = pd.read_csv('eo4.csv')

# Combine the DataFrames
df_combined = pd.concat([eo_pr, eo_xx, eo1, eo2, eo3, eo4])

# Print the combined DataFrame
print(df_combined)

# %%
df1 = pd.read_csv("eo1.csv")
df2 = pd.read_csv("eo2.csv")
df3 = pd.read_csv("eo3.csv")
df4 = pd.read_csv("eo4.csv")
df_pr = pd.read_csv("eo_pr.csv")
df_xx = pd.read_csv("eo_xx.csv")

# %%
# Combine the DataFrames
df_combined = pd.concat([eo_pr, eo_xx, eo1, eo2, eo3, eo4])

# Print the combined DataFrame
print(df_combined)
# Out:
#             EIN                                        NAME  \
# 0      10674605  IGLESIA FUENTE DE AGUA VIVA ORLANDO FL INC
# 1      10709908                          HOGARES AMPARO INC
# 2      20533102                       PATHSTONE CORPORATION
# 3      43700254   IGLESIA EVANGELICA MISIONERA FUERZA AGAPE
# 4      60602997                    TITI MILLIE DAY CARE INC
# ...         ...                                         ...
# 3319  990383004     JOHN E AND JANET E MCCULLOCH FOUNDATION
# 3320  990805980               IGLESIA CRISTIANA BETESDA INC
# 3321  993000079                     SAIPAN CHURCH OF CHRIST
# 3322  993006811             SAIPAN-PALAN EVANGELICAL CHURCH
# 3323  996016793       GEORGIA AUGUSTA UNIVERSITAT GOTTINGEN
#
#                                       ICO                       STREET  \
# 0                        % RODOLFO O FONT                  PO BOX 3869
# 1                  % CARMEN M CRUZ RIVERA     800 HIOODROMO ST STE 105
# 2                                     NaN                 1122 CALLE 5
# 3                         % ROBERT RANSOM                   PO BOX 580
# 4                                     NaN                  PO BOX 1347
# ...                                   ...                          ...
# 3319             % PATTERSON PARTNERS LTD               HAMILTON HM BX
# 3320      % IGLESIA CRISTIANA BETESDA INC  2605 CALLE VIVAS VALDIVIESO
# 3321                         % STEVE VICE                PO BOX 500549
# 3322                                  NaN                  PO BOX 5072
# 3323  % MARKUS HOPPE VP UNIV OF GOTTINGEN           ZU GOTTINGEN 37027
#
#              CITY STATE         ZIP  GROUP  SUBSECTION  AFFILIATION  ...  \
# 0        CAROLINA    PR  00984-3869      0           3            3  ...
# 1        SAN JUAN    PR  00909-0000      0           3            3  ...
# 2        SAN JUAN    PR  00927-5131   9113           3            9  ...
# 3     SAN ANTONIO    PR  00690-0580   2046           3            9  ...
# 4         GUANICA    PR  00653-1347      0           3            3  ...
# ...           ...   ...         ...    ...         ...          ...  ...
# 3319      BERMUDA   NaN  00000-0000      0           3            3  ...
# 3320        PONCE    PR  00728-3823   2046           3            9  ...
# 3321       SAIPAN    MP  96950-0549      0           3            3  ...
# 3322       SAIPAN    MP  96950-5072      0           3            3  ...
# 3323      GERMANY   NaN  00000-0000      0           3            3  ...
#
#       ASSET_CD  INCOME_CD  FILING_REQ_CD  PF_FILING_REQ_CD  ACCT_PD  \
# 0            0          0              6                 0       12
# 1            2          2              0                 1        6
# 2            0          0              1                 0        9
# 3            0          0              6                 0       12
# 4            3          4              1                 0        9
# ...        ...        ...            ...               ...      ...
# 3319         4          4              0                 1       12
# 3320         0          0              6                 0       12
# 3321         0          0              6                 0       12
# 3322         0          0              6                 0       12
# 3323         7          6              1                 0       12
#
#       ASSET_AMT  INCOME_AMT  REVENUE_AMT  NTEE_CD           SORT_NAME
# 0           NaN         NaN          NaN      X20                 NaN
# 1       20470.0     20509.0          NaN      P43                 NaN
# 2           NaN         NaN          NaN      NaN  PARQUE PLATINO INC
# 3           NaN         NaN          NaN      NaN                 NaN
# 4       78906.0    293493.0     293493.0      P33                 NaN
# ...         ...         ...          ...      ...                 ...
# 3319   387016.0    239237.0          NaN      T20                 NaN
# 3320        NaN         NaN          NaN      NaN    URB LAS DELICIAS
# 3321        NaN         NaN          NaN      X20                 NaN
# 3322        NaN         NaN          NaN      X20                 NaN
# 3323        NaN         NaN          NaN     B110                 NaN
#
# [1635278 rows x 28 columns]

# %%
df_combined.head()
# Out:
#         EIN                                        NAME  \
# 0  10674605  IGLESIA FUENTE DE AGUA VIVA ORLANDO FL INC
# 1  10709908                          HOGARES AMPARO INC
# 2  20533102                       PATHSTONE CORPORATION
# 3  43700254   IGLESIA EVANGELICA MISIONERA FUERZA AGAPE
# 4  60602997                    TITI MILLIE DAY CARE INC
#
#                       ICO                    STREET         CITY STATE  \
# 0        % RODOLFO O FONT               PO BOX 3869     CAROLINA    PR
# 1  % CARMEN M CRUZ RIVERA  800 HIOODROMO ST STE 105     SAN JUAN    PR
# 2                     NaN              1122 CALLE 5     SAN JUAN    PR
# 3         % ROBERT RANSOM                PO BOX 580  SAN ANTONIO    PR
# 4                     NaN               PO BOX 1347      GUANICA    PR
#
#           ZIP  GROUP  SUBSECTION  AFFILIATION  ...  ASSET_CD  INCOME_CD  \
# 0  00984-3869      0           3            3  ...         0          0
# 1  00909-0000      0           3            3  ...         2          2
# 2  00927-5131   9113           3            9  ...         0          0
# 3  00690-0580   2046           3            9  ...         0          0
# 4  00653-1347      0           3            3  ...         3          4
#
#    FILING_REQ_CD  PF_FILING_REQ_CD  ACCT_PD  ASSET_AMT  INCOME_AMT  \
# 0              6                 0       12        NaN         NaN
# 1              0                 1        6    20470.0     20509.0
# 2              1                 0        9        NaN         NaN
# 3              6                 0       12        NaN         NaN
# 4              1                 0        9    78906.0    293493.0
#
#    REVENUE_AMT  NTEE_CD           SORT_NAME
# 0          NaN      X20                 NaN
# 1          NaN      P43                 NaN
# 2          NaN      NaN  PARQUE PLATINO INC
# 3          NaN      NaN                 NaN
# 4     293493.0      P33                 NaN
#
# [5 rows x 28 columns]

# %%
df1.head()
# Out:
#       EIN                                              NAME  ICO  \
# 0   19818                      PALMER SECOND BAPTIST CHURCH  NaN
# 1   29215                               ST GEORGE CATHEDRAL  NaN
# 2  587764                              IGLESIA BETHESDA INC  NaN
# 3  635913  MINISTERIO APOSTOLICO JESUCRISTO ES EL SENOR INC  NaN
# 4  765634                        MERCY CHAPEL INTERNATIONAL  NaN
#
#                          STREET          CITY STATE         ZIP  GROUP  \
# 0             1050 THORNDIKE ST        PALMER    MA  01069-1507   3125
# 1                523 E BROADWAY  SOUTH BOSTON    MA  02127-4415   2365
# 2                157 ANDOVER ST        LOWELL    MA  01852-2348      0
# 3                  454 ESSEX ST      LAWRENCE    MA  01840-1242      0
# 4  75 MORTON VILLAGE DR APT 408      MATTAPAN    MA  02126-2433      0
#
#    SUBSECTION  AFFILIATION  ...  ASSET_CD  INCOME_CD  FILING_REQ_CD  \
# 0           3            9  ...         0          0              6
# 1           3            9  ...         0          0              6
# 2           3            3  ...         0          0              6
# 3           3            3  ...         0          0              6
# 4           3            3  ...         0          0              6
#
#    PF_FILING_REQ_CD  ACCT_PD  ASSET_AMT  INCOME_AMT  REVENUE_AMT  NTEE_CD  \
# 0                 0       12        NaN         NaN          NaN      NaN
# 1                 0       12        NaN         NaN          NaN      NaN
# 2                 0       12        NaN         NaN          NaN      X21
# 3                 0       12        NaN         NaN          NaN      X21
# 4                 0       12        NaN         NaN          NaN      X20
#
#    SORT_NAME
# 0       3514
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 28 columns]

# %%
df2.head()
# Out:
#         EIN                                  NAME                   ICO  \
# 0         1             VOLUNTEERS OF AMERICA INC                   NaN
# 1      3154      OAKLEAF FOREST TENANT MANAGEMENT                   NaN
# 2   2120849            ANCILLA DOMINI SISTERS INC                   NaN
# 3  10036381            DISABLED AMERICAN VETERANS  % BILLIENITA CARDONA
# 4  10060379  HEALING AND DELIVERANCE MINISTRY INC                   NaN
#
#                            STREET        CITY STATE         ZIP  GROUP  \
# 0  570 SOUTH FOURTH STREET NO 100  LOUISVILLE    KY  40202-2504   1736
# 1               1706 GREENLEAF DR     NORFOLK    VA  23523-2112      0
# 2                           LOCAL   DONALDSON    IN  46513-0000    928
# 3           15623 S CENTERLINE RD     RUDYARD    MI  49780-9349    557
# 4       201 E PATRICK ST UNIT 249   FREDERICK    MD  21705-7511      0
#
#    SUBSECTION  AFFILIATION  ...  ASSET_CD  INCOME_CD  FILING_REQ_CD  \
# 0           3            9  ...         0          0              1
# 1           3            3  ...         0          0              2
# 2           3            9  ...         0          0              6
# 3           4            9  ...         0          0              2
# 4           3            3  ...         0          0              6
#
#    PF_FILING_REQ_CD  ACCT_PD  ASSET_AMT  INCOME_AMT  REVENUE_AMT  NTEE_CD  \
# 0                 0        6        0.0         0.0          0.0      NaN
# 1                 0        6        NaN         NaN          NaN      S20
# 2                 0       12        NaN         NaN          NaN      NaN
# 3                 0        6        0.0         0.0          0.0      NaN
# 4                 0       12        NaN         NaN          NaN      X20
#
#                 SORT_NAME
# 0  VOAKY HOPEFUL ROAD INC
# 1                     NaN
# 2                     NaN
# 3              93 STRAITS
# 4                     NaN
#
# [5 rows x 28 columns]

# %%
df3.head()
# Out:
#        EIN                                          NAME  ICO  \
# 0   260049                        CORINTH BAPTIST CHURCH  NaN
# 1   360268                              IGLESIA VICTORIA  NaN
# 2   490336                       EASTSIDE BAPTIST CHURCH  NaN
# 3  2296179  RELIGIOUS SCIENCE CHURCH CENTER OF SAN DIEGO  NaN
# 4  3140260                        PILGRIM BAPTIST CHURCH  NaN
#
#                  STREET         CITY STATE         ZIP  GROUP  SUBSECTION  \
# 0             PO BOX 92      HOSFORD    FL  32334-0092   2024           3
# 1  1445 N BOONVILLE AVE  SPRINGFIELD    MO  65802-1894   1678           3
# 2            PO BOX 296      LABELLE    FL  33975-0296   2024           3
# 3      4102 MARLBOROUGH    SAN DIEGO    CA  92105-1462      0           3
# 4        217 N GRANT ST    SAN MATEO    CA  94401-1833   3125           3
#
#    AFFILIATION  ...  ASSET_CD  INCOME_CD  FILING_REQ_CD  PF_FILING_REQ_CD  \
# 0            9  ...         0          0              6                 0
# 1            9  ...         0          0              6                 0
# 2            9  ...         0          0              6                 0
# 3            3  ...         0          0              6                 0
# 4            9  ...         0          0              6                 0
#
#    ACCT_PD  ASSET_AMT  INCOME_AMT  REVENUE_AMT  NTEE_CD  SORT_NAME
# 0       12        NaN         NaN          NaN      NaN        NaN
# 1       12        NaN         NaN          NaN      NaN        NaN
# 2       12        NaN         NaN          NaN      NaN        NaN
# 3        3        NaN         NaN          NaN      NaN        NaN
# 4       12        NaN         NaN          NaN      NaN       1910
#
# [5 rows x 28 columns]

# %%
df4.head()
# Out:
#         EIN                                        NAME  \
# 0  10456167                             CHRYSALIS PLACE
# 1  10674605  IGLESIA FUENTE DE AGUA VIVA ORLANDO FL INC
# 2  10674736              US-JAPAN RELATIONSHIP FUND INC
# 3  10709908                          HOGARES AMPARO INC
# 4  10728628                           INTERSECTIONS INC
#
#                       ICO                      STREET       CITY STATE  \
# 0                     NaN           GARDINER ME 04345   AKROTIRI   NaN
# 1        % RODOLFO O FONT                 PO BOX 3869   CAROLINA    PR
# 2       % TATSUHIKO WAKAO  KAWASAKI KANAGAWA 216-0033      JAPAN   NaN
# 3  % CARMEN M CRUZ RIVERA    800 HIOODROMO ST STE 105   SAN JUAN    PR
# 4                     NaN                 PO BOX 1715  PAGO PAGO    AS
#
#           ZIP  GROUP  SUBSECTION  AFFILIATION  ...  ASSET_CD  INCOME_CD  \
# 0  00000-0000      0           3            3  ...         0          0
# 1  00984-3869      0           3            3  ...         0          0
# 2  00000-0000      0           3            3  ...         1          1
# 3  00909-0000      0           3            3  ...         2          2
# 4  96799-1715      0           3            3  ...         0          0
#
#    FILING_REQ_CD  PF_FILING_REQ_CD  ACCT_PD  ASSET_AMT  INCOME_AMT  \
# 0              2                 0       12        0.0         0.0
# 1              6                 0       12        NaN         NaN
# 2              2                 0       12     5434.0        10.0
# 3              0                 1        6    20470.0     20509.0
# 4              2                 0       12        0.0         0.0
#
#    REVENUE_AMT  NTEE_CD  SORT_NAME
# 0          0.0      NaN        NaN
# 1          NaN      X20        NaN
# 2         10.0      Q20        NaN
# 3          NaN      P43        NaN
# 4          0.0      O50        NaN
#
# [5 rows x 28 columns]

# %%
df_pr.head()
# Out:
#         EIN                                        NAME  \
# 0  10674605  IGLESIA FUENTE DE AGUA VIVA ORLANDO FL INC
# 1  10709908                          HOGARES AMPARO INC
# 2  20533102                       PATHSTONE CORPORATION
# 3  43700254   IGLESIA EVANGELICA MISIONERA FUERZA AGAPE
# 4  60602997                    TITI MILLIE DAY CARE INC
#
#                       ICO                    STREET         CITY STATE  \
# 0        % RODOLFO O FONT               PO BOX 3869     CAROLINA    PR
# 1  % CARMEN M CRUZ RIVERA  800 HIOODROMO ST STE 105     SAN JUAN    PR
# 2                     NaN              1122 CALLE 5     SAN JUAN    PR
# 3         % ROBERT RANSOM                PO BOX 580  SAN ANTONIO    PR
# 4                     NaN               PO BOX 1347      GUANICA    PR
#
#           ZIP  GROUP  SUBSECTION  AFFILIATION  ...  ASSET_CD  INCOME_CD  \
# 0  00984-3869      0           3            3  ...         0          0
# 1  00909-0000      0           3            3  ...         2          2
# 2  00927-5131   9113           3            9  ...         0          0
# 3  00690-0580   2046           3            9  ...         0          0
# 4  00653-1347      0           3            3  ...         3          4
#
#    FILING_REQ_CD  PF_FILING_REQ_CD  ACCT_PD  ASSET_AMT  INCOME_AMT  \
# 0              6                 0       12        NaN         NaN
# 1              0                 1        6    20470.0     20509.0
# 2              1                 0        9        NaN         NaN
# 3              6                 0       12        NaN         NaN
# 4              1                 0        9    78906.0    293493.0
#
#    REVENUE_AMT  NTEE_CD           SORT_NAME
# 0          NaN      X20                 NaN
# 1          NaN      P43                 NaN
# 2          NaN      NaN  PARQUE PLATINO INC
# 3          NaN      NaN                 NaN
# 4     293493.0      P33                 NaN
#
# [5 rows x 28 columns]

# %%
df_xx.head()
# Out:
#         EIN                             NAME                          ICO  \
# 0  10456167                  CHRYSALIS PLACE                          NaN
# 1  10674736   US-JAPAN RELATIONSHIP FUND INC            % TATSUHIKO WAKAO
# 2  10728628                INTERSECTIONS INC                          NaN
# 3  20674899   ARIEL FOUNDATION INTERNATIONAL             % ROY MORRIS ESQ
# 4  30387180  NEW LAKEWOOD SCOUT SPONSORS INC  % KAREN STEINFELD SECRETARY
#
#                        STREET         CITY STATE         ZIP  GROUP  \
# 0           GARDINER ME 04345     AKROTIRI   NaN  00000-0000      0
# 1  KAWASAKI KANAGAWA 216-0033        JAPAN   NaN  00000-0000      0
# 2                 PO BOX 1715    PAGO PAGO    AS  96799-1715      0
# 3              GENEVA CH-1216  SWITZERLAND   NaN  00000-0000      0
# 4          ROCKVILLE MD 20850  AFGHANISTAN   NaN  00000-0000      0
#
#    SUBSECTION  AFFILIATION  ...  ASSET_CD  INCOME_CD  FILING_REQ_CD  \
# 0           3            3  ...         0          0              2
# 1           3            3  ...         1          1              2
# 2           3            3  ...         0          0              2
# 3           3            3  ...         0          0              2
# 4           3            3  ...         0          0              2
#
#    PF_FILING_REQ_CD  ACCT_PD  ASSET_AMT  INCOME_AMT  REVENUE_AMT  NTEE_CD  \
# 0                 0       12        0.0         0.0          0.0      NaN
# 1                 0       12     5434.0        10.0         10.0      Q20
# 2                 0       12        0.0         0.0          0.0      O50
# 3                 0       12        0.0         0.0          0.0      Q30
# 4                 0        8        0.0         0.0          0.0     O114
#
#     SORT_NAME
# 0         NaN
# 1         NaN
# 2         NaN
# 3  ARIEL KING
# 4         NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Get to Know the Numbers
#
# Now that you have everything setup, put any code that you use to get to know the dataframe and its rows and columns better in the cell below. You can use whatever techniques you like, except for visualizations. You will put those in a separate section.
#
# When working on your code, make sure to leave comments so that your mentors can understand your thought process.

# %%
print(df_combined.columns.values)
# Out:
# ['EIN' 'NAME' 'ICO' 'STREET' 'CITY' 'STATE' 'ZIP' 'GROUP' 'SUBSECTION'
#  'AFFILIATION' 'CLASSIFICATION' 'RULING' 'DEDUCTIBILITY' 'FOUNDATION'
#  'ACTIVITY' 'ORGANIZATION' 'STATUS' 'TAX_PERIOD' 'ASSET_CD' 'INCOME_CD'
#  'FILING_REQ_CD' 'PF_FILING_REQ_CD' 'ACCT_PD' 'ASSET_AMT' 'INCOME_AMT'
#  'REVENUE_AMT' 'NTEE_CD' 'SORT_NAME']

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1635278 entries, 0 to 3323
# Data columns (total 28 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   EIN               1635278 non-null  int64
#  1   NAME              1635278 non-null  object
#  2   ICO               1083138 non-null  object
#  3   STREET            1635274 non-null  object
#  4   CITY              1635278 non-null  object
#  5   STATE             1632858 non-null  object
#  6   ZIP               1635278 non-null  object
#  7   GROUP             1635278 non-null  int64
#  8   SUBSECTION        1635278 non-null  int64
#  9   AFFILIATION       1635278 non-null  int64
#  10  CLASSIFICATION    1635278 non-null  int64
#  11  RULING            1635278 non-null  int64
#  12  DEDUCTIBILITY     1635278 non-null  int64
#  13  FOUNDATION        1635278 non-null  int64
#  14  ACTIVITY          1635278 non-null  int64
#  15  ORGANIZATION      1635278 non-null  int64
#  16  STATUS            1635278 non-null  int64
#  17  TAX_PERIOD        1300333 non-null  float64
#  18  ASSET_CD          1635278 non-null  int64
#  19  INCOME_CD         1635278 non-null  int64
#  20  FILING_REQ_CD     1635278 non-null  int64
#  21  PF_FILING_REQ_CD  1635278 non-null  int64
#  22  ACCT_PD           1635278 non-null  int64
#  23  ASSET_AMT         1282994 non-null  float64
#  24  INCOME_AMT        1282994 non-null  float64
#  25  REVENUE_AMT       1175724 non-null  float64
#  26  NTEE_CD           976897 non-null   object
#  27  SORT_NAME         437916 non-null   object
# dtypes: float64(4), int64(16), object(8)
# memory usage: 361.8+ MB

# %%
columns_to_drop = ['ICO', 'TAX_PERIOD', 'ASSET_AMT', 'INCOME_AMT', 'REVENUE_AMT', 'NTEE_CD', 'SORT_NAME']
df_combined_dropped = df_combined.drop(columns=columns_to_drop)
print(df_combined_dropped)
# Out:
#             EIN                                        NAME  \
# 0      10674605  IGLESIA FUENTE DE AGUA VIVA ORLANDO FL INC
# 1      10709908                          HOGARES AMPARO INC
# 2      20533102                       PATHSTONE CORPORATION
# 3      43700254   IGLESIA EVANGELICA MISIONERA FUERZA AGAPE
# 4      60602997                    TITI MILLIE DAY CARE INC
# ...         ...                                         ...
# 3319  990383004     JOHN E AND JANET E MCCULLOCH FOUNDATION
# 3320  990805980               IGLESIA CRISTIANA BETESDA INC
# 3321  993000079                     SAIPAN CHURCH OF CHRIST
# 3322  993006811             SAIPAN-PALAN EVANGELICAL CHURCH
# 3323  996016793       GEORGIA AUGUSTA UNIVERSITAT GOTTINGEN
#
#                            STREET         CITY STATE         ZIP  GROUP  \
# 0                     PO BOX 3869     CAROLINA    PR  00984-3869      0
# 1        800 HIOODROMO ST STE 105     SAN JUAN    PR  00909-0000      0
# 2                    1122 CALLE 5     SAN JUAN    PR  00927-5131   9113
# 3                      PO BOX 580  SAN ANTONIO    PR  00690-0580   2046
# 4                     PO BOX 1347      GUANICA    PR  00653-1347      0
# ...                           ...          ...   ...         ...    ...
# 3319               HAMILTON HM BX      BERMUDA   NaN  00000-0000      0
# 3320  2605 CALLE VIVAS VALDIVIESO        PONCE    PR  00728-3823   2046
# 3321                PO BOX 500549       SAIPAN    MP  96950-0549      0
# 3322                  PO BOX 5072       SAIPAN    MP  96950-5072      0
# 3323           ZU GOTTINGEN 37027      GERMANY   NaN  00000-0000      0
#
#       SUBSECTION  AFFILIATION  CLASSIFICATION  ...  DEDUCTIBILITY  FOUNDATION  \
# 0              3            3            7000  ...              1          10
# 1              3            3            1000  ...              1           4
# 2              3            9            1000  ...              1          15
# 3              3            9            7000  ...              1          10
# 4              3            3            1000  ...              1          15
# ...          ...          ...             ...  ...            ...         ...
# 3319           3            3            1000  ...              1           4
# 3320           3            9            7000  ...              1          10
# 3321           3            3            7000  ...              1          10
# 3322           3            3            7000  ...              1          10
# 3323           3            3            1000  ...              1          14
#
#        ACTIVITY  ORGANIZATION  STATUS  ASSET_CD  INCOME_CD  FILING_REQ_CD  \
# 0             0             1       1         0          0              6
# 1             0             1       1         2          2              0
# 2     994566560             1       1         0          0              1
# 3       1000000             5       1         0          0              6
# 4             0             1       1         3          4              1
# ...         ...           ...     ...       ...        ...            ...
# 3319          0             1       1         4          4              0
# 3320    1000000             5       1         0          0              6
# 3321          0             1       1         0          0              6
# 3322          0             1       1         0          0              6
# 3323   30000000             5       1         7          6              1
#
#       PF_FILING_REQ_CD  ACCT_PD
# 0                    0       12
# 1                    1        6
# 2                    0        9
# 3                    0       12
# 4                    0        9
# ...                ...      ...
# 3319                 1       12
# 3320                 0       12
# 3321                 0       12
# 3322                 0       12
# 3323                 0       12
#
# [1635278 rows x 21 columns]

# %%
duplicates = df_combined_dropped[df_combined_dropped.duplicated()]
print(duplicates)
# Out:
#             EIN                                        NAME  \
# 0      10456167                             CHRYSALIS PLACE
# 1      10674605  IGLESIA FUENTE DE AGUA VIVA ORLANDO FL INC
# 2      10674736              US-JAPAN RELATIONSHIP FUND INC
# 3      10709908                          HOGARES AMPARO INC
# 4      10728628                           INTERSECTIONS INC
# ...         ...                                         ...
# 3319  990383004     JOHN E AND JANET E MCCULLOCH FOUNDATION
# 3320  990805980               IGLESIA CRISTIANA BETESDA INC
# 3321  993000079                     SAIPAN CHURCH OF CHRIST
# 3322  993006811             SAIPAN-PALAN EVANGELICAL CHURCH
# 3323  996016793       GEORGIA AUGUSTA UNIVERSITAT GOTTINGEN
#
#                            STREET       CITY STATE         ZIP  GROUP  \
# 0               GARDINER ME 04345   AKROTIRI   NaN  00000-0000      0
# 1                     PO BOX 3869   CAROLINA    PR  00984-3869      0
# 2      KAWASAKI KANAGAWA 216-0033      JAPAN   NaN  00000-0000      0
# 3        800 HIOODROMO ST STE 105   SAN JUAN    PR  00909-0000      0
# 4                     PO BOX 1715  PAGO PAGO    AS  96799-1715      0
# ...                           ...        ...   ...         ...    ...
# 3319               HAMILTON HM BX    BERMUDA   NaN  00000-0000      0
# 3320  2605 CALLE VIVAS VALDIVIESO      PONCE    PR  00728-3823   2046
# 3321                PO BOX 500549     SAIPAN    MP  96950-0549      0
# 3322                  PO BOX 5072     SAIPAN    MP  96950-5072      0
# 3323           ZU GOTTINGEN 37027    GERMANY   NaN  00000-0000      0
#
#       SUBSECTION  AFFILIATION  CLASSIFICATION  ...  DEDUCTIBILITY  FOUNDATION  \
# 0              3            3            1000  ...              1          15
# 1              3            3            7000  ...              1          10
# 2              3            3            1200  ...              1          15
# 3              3            3            1000  ...              1           4
# 4              3            3            1000  ...              1          15
# ...          ...          ...             ...  ...            ...         ...
# 3319           3            3            1000  ...              1           4
# 3320           3            9            7000  ...              1          10
# 3321           3            3            7000  ...              1          10
# 3322           3            3            7000  ...              1          10
# 3323           3            3            1000  ...              1          14
#
#        ACTIVITY  ORGANIZATION  STATUS  ASSET_CD  INCOME_CD  FILING_REQ_CD  \
# 0     994408560             1       1         0          0              2
# 1             0             1       1         0          0              6
# 2             0             1       1         1          1              2
# 3             0             1       1         2          2              0
# 4             0             1       1         0          0              2
# ...         ...           ...     ...       ...        ...            ...
# 3319          0             1       1         4          4              0
# 3320    1000000             5       1         0          0              6
# 3321          0             1       1         0          0              6
# 3322          0             1       1         0          0              6
# 3323   30000000             5       1         7          6              1
#
#       PF_FILING_REQ_CD  ACCT_PD
# 0                    0       12
# 1                    0       12
# 2                    0       12
# 3                    1        6
# 4                    0       12
# ...                ...      ...
# 3319                 1       12
# 3320                 0       12
# 3321                 0       12
# 3322                 0       12
# 3323                 0       12
#
# [3324 rows x 21 columns]

# %%
duplicates = df_combined_dropped[df_combined_dropped.duplicated(keep=False)]
print(duplicates)
# Out:
#             EIN                                        NAME  \
# 0      10674605  IGLESIA FUENTE DE AGUA VIVA ORLANDO FL INC
# 1      10709908                          HOGARES AMPARO INC
# 2      20533102                       PATHSTONE CORPORATION
# 3      43700254   IGLESIA EVANGELICA MISIONERA FUERZA AGAPE
# 4      60602997                    TITI MILLIE DAY CARE INC
# ...         ...                                         ...
# 3319  990383004     JOHN E AND JANET E MCCULLOCH FOUNDATION
# 3320  990805980               IGLESIA CRISTIANA BETESDA INC
# 3321  993000079                     SAIPAN CHURCH OF CHRIST
# 3322  993006811             SAIPAN-PALAN EVANGELICAL CHURCH
# 3323  996016793       GEORGIA AUGUSTA UNIVERSITAT GOTTINGEN
#
#                            STREET         CITY STATE         ZIP  GROUP  \
# 0                     PO BOX 3869     CAROLINA    PR  00984-3869      0
# 1        800 HIOODROMO ST STE 105     SAN JUAN    PR  00909-0000      0
# 2                    1122 CALLE 5     SAN JUAN    PR  00927-5131   9113
# 3                      PO BOX 580  SAN ANTONIO    PR  00690-0580   2046
# 4                     PO BOX 1347      GUANICA    PR  00653-1347      0
# ...                           ...          ...   ...         ...    ...
# 3319               HAMILTON HM BX      BERMUDA   NaN  00000-0000      0
# 3320  2605 CALLE VIVAS VALDIVIESO        PONCE    PR  00728-3823   2046
# 3321                PO BOX 500549       SAIPAN    MP  96950-0549      0
# 3322                  PO BOX 5072       SAIPAN    MP  96950-5072      0
# 3323           ZU GOTTINGEN 37027      GERMANY   NaN  00000-0000      0
#
#       SUBSECTION  AFFILIATION  CLASSIFICATION  ...  DEDUCTIBILITY  FOUNDATION  \
# 0              3            3            7000  ...              1          10
# 1              3            3            1000  ...              1           4
# 2              3            9            1000  ...              1          15
# 3              3            9            7000  ...              1          10
# 4              3            3            1000  ...              1          15
# ...          ...          ...             ...  ...            ...         ...
# 3319           3            3            1000  ...              1           4
# 3320           3            9            7000  ...              1          10
# 3321           3            3            7000  ...              1          10
# 3322           3            3            7000  ...              1          10
# 3323           3            3            1000  ...              1          14
#
#        ACTIVITY  ORGANIZATION  STATUS  ASSET_CD  INCOME_CD  FILING_REQ_CD  \
# 0             0             1       1         0          0              6
# 1             0             1       1         2          2              0
# 2     994566560             1       1         0          0              1
# 3       1000000             5       1         0          0              6
# 4             0             1       1         3          4              1
# ...         ...           ...     ...       ...        ...            ...
# 3319          0             1       1         4          4              0
# 3320    1000000             5       1         0          0              6
# 3321          0             1       1         0          0              6
# 3322          0             1       1         0          0              6
# 3323   30000000             5       1         7          6              1
#
#       PF_FILING_REQ_CD  ACCT_PD
# 0                    0       12
# 1                    1        6
# 2                    0        9
# 3                    0       12
# 4                    0        9
# ...                ...      ...
# 3319                 1       12
# 3320                 0       12
# 3321                 0       12
# 3322                 0       12
# 3323                 0       12
#
# [6648 rows x 21 columns]

# %%
df_combined_dropped = df_combined_dropped.drop_duplicates()
print(df_combined_dropped)
# Out:
#               EIN                                        NAME  \
# 0        10674605  IGLESIA FUENTE DE AGUA VIVA ORLANDO FL INC
# 1        10709908                          HOGARES AMPARO INC
# 2        20533102                       PATHSTONE CORPORATION
# 3        43700254   IGLESIA EVANGELICA MISIONERA FUERZA AGAPE
# 4        60602997                    TITI MILLIE DAY CARE INC
# ...           ...                                         ...
# 768917  996088748                          UNOYO KOJIMA TRUST
# 768918  996089401                 TOYO SAKUMOTO CHARITABLE TR
# 768919  996165005            INDEPENDENT ORDER OF ODD FELLOWS
# 768920  998010224             HAWAII FOUNDATION FOR THE BLIND
# 768921  999009356     NATIONAL ASSOCIATION OF LETTER CARRIERS
#
#                              STREET         CITY STATE         ZIP  GROUP  \
# 0                       PO BOX 3869     CAROLINA    PR  00984-3869      0
# 1          800 HIOODROMO ST STE 105     SAN JUAN    PR  00909-0000      0
# 2                      1122 CALLE 5     SAN JUAN    PR  00927-5131   9113
# 3                        PO BOX 580  SAN ANTONIO    PR  00690-0580   2046
# 4                       PO BOX 1347      GUANICA    PR  00653-1347      0
# ...                             ...          ...   ...         ...    ...
# 768917                  PO BOX 3170     HONOLULU    HI  96802-3170      0
# 768918                  PO BOX 3170     HONOLULU    HI  96802-3170      0
# 768919                    PO BOX 76    CUPERTINO    CA  95015-0076     28
# 768920  225 LILIUOKALANI AVE APT 5D     HONOLULU    HI  96815-3509      0
# 768921                 PO BOX 25854     HONOLULU    HI  96825-0854      0
#
#         SUBSECTION  AFFILIATION  CLASSIFICATION  ...  DEDUCTIBILITY  \
# 0                3            3            7000  ...              1
# 1                3            3            1000  ...              1
# 2                3            9            1000  ...              1
# 3                3            9            7000  ...              1
# 4                3            3            1000  ...              1
# ...            ...          ...             ...  ...            ...
# 768917           3            3            1000  ...              1
# 768918           3            3            1000  ...              1
# 768919           8            9            1000  ...              1
# 768920           3            3            2000  ...              1
# 768921           5            3            3000  ...              2
#
#         FOUNDATION   ACTIVITY  ORGANIZATION  STATUS  ASSET_CD  INCOME_CD  \
# 0               10          0             1       1         0          0
# 1                4          0             1       1         2          2
# 2               15  994566560             1       1         0          0
# 3               10    1000000             5       1         0          0
# 4               15          0             1       1         3          4
# ...            ...        ...           ...     ...       ...        ...
# 768917           4          0             1       1         4          4
# 768918           4          0             5       1         5          3
# 768919           0   36382265             5       1         0          0
# 768920           3  160000000             1       1         5          4
# 768921           0  263264279             5       1         0          0
#
#         FILING_REQ_CD  PF_FILING_REQ_CD  ACCT_PD
# 0                   6                 0       12
# 1                   0                 1        6
# 2                   1                 0        9
# 3                   6                 0       12
# 4                   1                 0        9
# ...               ...               ...      ...
# 768917              0                 1        3
# 768918              0                 1        3
# 768919              2                 0       12
# 768920              0                 1       12
# 768921              2                 0       12
#
# [1631954 rows x 21 columns]

# %%
# Get general information about the dataframes
# Print the shape of each dataframe
print("df_pr shape:", df_pr.shape)
print("df_xx shape:", df_xx.shape)
print("df1 shape:", df1.shape)
print("df2 shape:", df2.shape)
print("df3 shape:", df3.shape)
print("df4 shape:", df4.shape)
print("df_combined shape:", df_combined.shape)

# Print the column names of each dataframe
print("df_pr columns:", df_pr.columns)
print("df_xx columns:", df_xx.columns)
print("df1 columns:", df1.columns)
print("df2 columns:", df2.columns)
print("df3 columns:", df3.columns)
print("df4 columns:", df4.columns)
print("df_combined columns:", df_combined.columns)

# Get summary statistics for each dataframe
print("df_combined summary statistics:")
print(df_combined.describe())

print("df_pr summary statistics:")
print(df_pr.describe())

print("df_xx summary statistics:")
print(df_xx.describe())

print("df1 summary statistics:")
print(df1.describe())

print("df2 summary statistics:")
print(df2.describe())

print("df3 summary statistics:")
print(df3.describe())

print("df4 summary statistics:")
print(df4.describe())

# Display sample rows from each dataframe
print("Sample rows from df_pr:")
print(df_pr.head())

print("Sample rows from df_xx:")
print(df_xx.head())

print("Sample rows from df1:")
print(df1.head())

print("Sample rows from df2:")
print(df2.head())

print("Sample rows from df3:")
print(df3.head())

print("Sample rows from df4:")
print(df4.head())
# Out:
# df_pr shape: (1351, 28)
# df_xx shape: (1973, 28)
# df1 shape: (240579, 28)
# df2 shape: (619129, 28)
# df3 shape: (768922, 28)
# df4 shape: (3324, 28)
# df_combined shape: (1635278, 28)
# df_pr columns: Index(['EIN', 'NAME', 'ICO', 'STREET', 'CITY', 'STATE', 'ZIP', 'GROUP',
#        'SUBSECTION', 'AFFILIATION', 'CLASSIFICATION', 'RULING',
#        'DEDUCTIBILITY', 'FOUNDATION', 'ACTIVITY', 'ORGANIZATION', 'STATUS',
#        'TAX_PERIOD', 'ASSET_CD', 'INCOME_CD', 'FILING_REQ_CD',
#        'PF_FILING_REQ_CD', 'ACCT_PD', 'ASSET_AMT', 'INCOME_AMT', 'REVENUE_AMT',
#        'NTEE_CD', 'SORT_NAME'],
#       dtype='object')
# df_xx columns: Index(['EIN', 'NAME', 'ICO', 'STREET', 'CITY', 'STATE', 'ZIP', 'GROUP',
#        'SUBSECTION', 'AFFILIATION', 'CLASSIFICATION', 'RULING',
#        'DEDUCTIBILITY', 'FOUNDATION', 'ACTIVITY', 'ORGANIZATION', 'STATUS',
#        'TAX_PERIOD', 'ASSET_CD', 'INCOME_CD', 'FILING_REQ_CD',
#        'PF_FILING_REQ_CD', 'ACCT_PD', 'ASSET_AMT', 'INCOME_AMT', 'REVENUE_AMT',
#        'NTEE_CD', 'SORT_NAME'],
#       dtype='object')
# df1 columns: Index(['EIN', 'NAME', 'ICO', 'STREET', 'CITY', 'STATE', 'ZIP', 'GROUP',
#        'SUBSECTION', 'AFFILIATION', 'CLASSIFICATION', 'RULING',
#        'DEDUCTIBILITY', 'FOUNDATION', 'ACTIVITY', 'ORGANIZATION', 'STATUS',
#        'TAX_PERIOD', 'ASSET_CD', 'INCOME_CD', 'FILING_REQ_CD',
#        'PF_FILING_REQ_CD', 'ACCT_PD', 'ASSET_AMT', 'INCOME_AMT', 'REVENUE_AMT',
#        'NTEE_CD', 'SORT_NAME'],
#       dtype='object')
# df2 columns: Index(['EIN', 'NAME', 'ICO', 'STREET', 'CITY', 'STATE', 'ZIP', 'GROUP',
#        'SUBSECTION', 'AFFILIATION', 'CLASSIFICATION', 'RULING',
#        'DEDUCTIBILITY', 'FOUNDATION', 'ACTIVITY', 'ORGANIZATION', 'STATUS',
#        'TAX_PERIOD', 'ASSET_CD', 'INCOME_CD', 'FILING_REQ_CD',
#        'PF_FILING_REQ_CD', 'ACCT_PD', 'ASSET_AMT', 'INCOME_AMT', 'REVENUE_AMT',
#        'NTEE_CD', 'SORT_NAME'],
#       dtype='object')
# df3 columns: Index(['EIN', 'NAME', 'ICO', 'STREET', 'CITY', 'STATE', 'ZIP', 'GROUP',
#        'SUBSECTION', 'AFFILIATION', 'CLASSIFICATION', 'RULING',
#        'DEDUCTIBILITY', 'FOUNDATION', 'ACTIVITY', 'ORGANIZATION', 'STATUS',
#        'TAX_PERIOD', 'ASSET_CD', 'INCOME_CD', 'FILING_REQ_CD',
#        'PF_FILING_REQ_CD', 'ACCT_PD', 'ASSET_AMT', 'INCOME_AMT', 'REVENUE_AMT',
#        'NTEE_CD', 'SORT_NAME'],
#       dtype='object')
# df4 columns: Index(['EIN', 'NAME', 'ICO', 'STREET', 'CITY', 'STATE', 'ZIP', 'GROUP',
#        'SUBSECTION', 'AFFILIATION', 'CLASSIFICATION', 'RULING',
#        'DEDUCTIBILITY', 'FOUNDATION', 'ACTIVITY', 'ORGANIZATION', 'STATUS',
#        'TAX_PERIOD', 'ASSET_CD', 'INCOME_CD', 'FILING_REQ_CD',
#        'PF_FILING_REQ_CD', 'ACCT_PD', 'ASSET_AMT', 'INCOME_AMT', 'REVENUE_AMT',
#        'NTEE_CD', 'SORT_NAME'],
#       dtype='object')
# df_combined columns: Index(['EIN', 'NAME', 'ICO', 'STREET', 'CITY', 'STATE', 'ZIP', 'GROUP',
#        'SUBSECTION', 'AFFILIATION', 'CLASSIFICATION', 'RULING',
#        'DEDUCTIBILITY', 'FOUNDATION', 'ACTIVITY', 'ORGANIZATION', 'STATUS',
#        'TAX_PERIOD', 'ASSET_CD', 'INCOME_CD', 'FILING_REQ_CD',
#        'PF_FILING_REQ_CD', 'ACCT_PD', 'ASSET_AMT', 'INCOME_AMT', 'REVENUE_AMT',
#        'NTEE_CD', 'SORT_NAME'],
#       dtype='object')
# df_combined summary statistics:
#                 EIN         GROUP    SUBSECTION   AFFILIATION  CLASSIFICATION  \
# count  1.635278e+06  1.635278e+06  1.635278e+06  1.635278e+06    1.635278e+06
# mean   4.721234e+08  7.523340e+02  4.346013e+00  4.638687e+00    2.276860e+03
# std    2.466882e+08  1.856847e+03  6.323481e+00  2.694518e+00    2.125220e+03
# min    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00    0.000000e+00
# 25
# 75%    6.608609e+08     0.00000     3.000000     3.000000     2700.000000
# max    9.960168e+08  9524.00000    92.000000     9.000000     8200.000000
#
#               RULING  DEDUCTIBILITY   FOUNDATION      ACTIVITY  ORGANIZATION  \
# count    3324.000000    3324.000000  3324.000000  3.324000e+03   3324.000000
# mean   198432.818893       1.429603    11.176294  1.030180e+08      1.942840
# std     14390.699294       0.906480     5.474442  2.431273e+08      1.682891
# min         0.000000       0.000000     0.000000  0.000000e+00      0.000000
# 25%    198078.750000       1.000000    10.000000  0.000000e+00      1.000000
# 50%    200201.000000       1.000000    15.000000  0.000000e+00      1.000000
# 75%    201309.000000       2.000000    15.000000  4.018350e+07      2.000000
# max    201707.000000       4.000000    23.000000  9.990000e+08      6.000000
#
#             STATUS     TAX_PERIOD     ASSET_CD    INCOME_CD  FILING_REQ_CD  \
# count  3324.000000    2408.000000  3324.000000  3324.000000    3324.000000
# mean      1.024368  201561.237542     2.258424     2.172684       2.404031
# std       0.596162      97.753941     2.939710     2.793251       2.319006
# min       1.000000  200012.000000     0.000000     0.000000       0.000000
# 25%       1.000000  201512.000000     0.000000     0.000000       1.000000
# 50%       1.000000  201606.000000     0.000000     0.000000       2.000000
# 75%       1.000000  201612.000000     4.000000     4.000000       2.000000
# max      25.000000  201706.000000     9.000000     9.000000      14.000000
#
#        PF_FILING_REQ_CD      ACCT_PD     ASSET_AMT    INCOME_AMT   REVENUE_AMT
# count       3324.000000  3324.000000  2.386000e+03  2.386000e+03  2.228000e+03
# mean           0.058965     9.910048  7.005721e+07  2.740353e+07  1.823468e+07
# std            0.243138     3.118104  7.967388e+08  4.346149e+08  1.572083e+08
# min            0.000000     1.000000  0.000000e+00 -3.266150e+05 -5.883770e+05
# 25%            0.000000     7.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 50%            0.000000    12.000000  3.783800e+04  5.997400e+04  4.292000e+04
# 75%            0.000000    12.000000  1.080998e+06  7.110855e+05  6.448462e+05
# max            3.000000    12.000000  3.155665e+10  1.976347e+10  5.128140e+09
# Sample rows from df_pr:
#         EIN                                        NAME  \
# 0  10674605  IGLESIA FUENTE DE AGUA VIVA ORLANDO FL INC
# 1  10709908                          HOGARES AMPARO INC
# 2  20533102                       PATHSTONE CORPORATION
# 3  43700254   IGLESIA EVANGELICA MISIONERA FUERZA AGAPE
# 4  60602997                    TITI MILLIE DAY CARE INC
#
#                       ICO                    STREET         CITY STATE  \
# 0        % RODOLFO O FONT               PO BOX 3869     CAROLINA    PR
# 1  % CARMEN M CRUZ RIVERA  800 HIOODROMO ST STE 105     SAN JUAN    PR
# 2                     NaN              1122 CALLE 5     SAN JUAN    PR
# 3         % ROBERT RANSOM                PO BOX 580  SAN ANTONIO    PR
# 4                     NaN               PO BOX 1347      GUANICA    PR
#
#           ZIP  GROUP  SUBSECTION  AFFILIATION  ...  ASSET_CD  INCOME_CD  \
# 0  00984-3869      0           3            3  ...         0          0
# 1  00909-0000      0           3            3  ...         2          2
# 2  00927-5131   9113           3            9  ...         0          0
# 3  00690-0580   2046           3            9  ...         0          0
# 4  00653-1347      0           3            3  ...         3          4
#
#    FILING_REQ_CD  PF_FILING_REQ_CD  ACCT_PD  ASSET_AMT  INCOME_AMT  \
# 0              6                 0       12        NaN         NaN
# 1              0                 1        6    20470.0     20509.0
# 2              1                 0        9        NaN         NaN
# 3              6                 0       12        NaN         NaN
# 4              1                 0        9    78906.0    293493.0
#
#    REVENUE_AMT  NTEE_CD           SORT_NAME
# 0          NaN      X20                 NaN
# 1          NaN      P43                 NaN
# 2          NaN      NaN  PARQUE PLATINO INC
# 3          NaN      NaN                 NaN
# 4     293493.0      P33                 NaN
#
# [5 rows x 28 columns]
# Sample rows from df_xx:
#         EIN                             NAME                          ICO  \
# 0  10456167                  CHRYSALIS PLACE                          NaN
# 1  10674736   US-JAPAN RELATIONSHIP FUND INC            % TATSUHIKO WAKAO
# 2  10728628                INTERSECTIONS INC                          NaN
# 3  20674899   ARIEL FOUNDATION INTERNATIONAL             % ROY MORRIS ESQ
# 4  30387180  NEW LAKEWOOD SCOUT SPONSORS INC  % KAREN STEINFELD SECRETARY
#
#                        STREET         CITY STATE         ZIP  GROUP  \
# 0           GARDINER ME 04345     AKROTIRI   NaN  00000-0000      0
# 1  KAWASAKI KANAGAWA 216-0033        JAPAN   NaN  00000-0000      0
# 2                 PO BOX 1715    PAGO PAGO    AS  96799-1715      0
# 3              GENEVA CH-1216  SWITZERLAND   NaN  00000-0000      0
# 4          ROCKVILLE MD 20850  AFGHANISTAN   NaN  00000-0000      0
#
#    SUBSECTION  AFFILIATION  ...  ASSET_CD  INCOME_CD  FILING_REQ_CD  \
# 0           3            3  ...         0          0              2
# 1           3            3  ...         1          1              2
# 2           3            3  ...         0          0              2
# 3           3            3  ...         0          0              2
# 4           3            3  ...         0          0              2
#
#    PF_FILING_REQ_CD  ACCT_PD  ASSET_AMT  INCOME_AMT  REVENUE_AMT  NTEE_CD  \
# 0                 0       12        0.0         0.0          0.0      NaN
# 1                 0       12     5434.0        10.0         10.0      Q20
# 2                 0       12        0.0         0.0          0.0      O50
# 3                 0       12        0.0         0.0          0.0      Q30
# 4                 0        8        0.0         0.0          0.0     O114
#
#     SORT_NAME
# 0         NaN
# 1         NaN
# 2         NaN
# 3  ARIEL KING
# 4         NaN
#
# [5 rows x 28 columns]
# Sample rows from df1:
#       EIN                                              NAME  ICO  \
# 0   19818                      PALMER SECOND BAPTIST CHURCH  NaN
# 1   29215                               ST GEORGE CATHEDRAL  NaN
# 2  587764                              IGLESIA BETHESDA INC  NaN
# 3  635913  MINISTERIO APOSTOLICO JESUCRISTO ES EL SENOR INC  NaN
# 4  765634                        MERCY CHAPEL INTERNATIONAL  NaN
#
#                          STREET          CITY STATE         ZIP  GROUP  \
# 0             1050 THORNDIKE ST        PALMER    MA  01069-1507   3125
# 1                523 E BROADWAY  SOUTH BOSTON    MA  02127-4415   2365
# 2                157 ANDOVER ST        LOWELL    MA  01852-2348      0
# 3                  454 ESSEX ST      LAWRENCE    MA  01840-1242      0
# 4  75 MORTON VILLAGE DR APT 408      MATTAPAN    MA  02126-2433      0
#
#    SUBSECTION  AFFILIATION  ...  ASSET_CD  INCOME_CD  FILING_REQ_CD  \
# 0           3            9  ...         0          0              6
# 1           3            9  ...         0          0              6
# 2           3            3  ...         0          0              6
# 3           3            3  ...         0          0              6
# 4           3            3  ...         0          0              6
#
#    PF_FILING_REQ_CD  ACCT_PD  ASSET_AMT  INCOME_AMT  REVENUE_AMT  NTEE_CD  \
# 0                 0       12        NaN         NaN          NaN      NaN
# 1                 0       12        NaN         NaN          NaN      NaN
# 2                 0       12        NaN         NaN          NaN      X21
# 3                 0       12        NaN         NaN          NaN      X21
# 4                 0       12        NaN         NaN          NaN      X20
#
#    SORT_NAME
# 0       3514
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 28 columns]
# Sample rows from df2:
#         EIN                                  NAME                   ICO  \
# 0         1             VOLUNTEERS OF AMERICA INC                   NaN
# 1      3154      OAKLEAF FOREST TENANT MANAGEMENT                   NaN
# 2   2120849            ANCILLA DOMINI SISTERS INC                   NaN
# 3  10036381            DISABLED AMERICAN VETERANS  % BILLIENITA CARDONA
# 4  10060379  HEALING AND DELIVERANCE MINISTRY INC                   NaN
#
#                            STREET        CITY STATE         ZIP  GROUP  \
# 0  570 SOUTH FOURTH STREET NO 100  LOUISVILLE    KY  40202-2504   1736
# 1               1706 GREENLEAF DR     NORFOLK    VA  23523-2112      0
# 2                           LOCAL   DONALDSON    IN  46513-0000    928
# 3           15623 S CENTERLINE RD     RUDYARD    MI  49780-9349    557
# 4       201 E PATRICK ST UNIT 249   FREDERICK    MD  21705-7511      0
#
#    SUBSECTION  AFFILIATION  ...  ASSET_CD  INCOME_CD  FILING_REQ_CD  \
# 0           3            9  ...         0          0              1
# 1           3            3  ...         0          0              2
# 2           3            9  ...         0          0              6
# 3           4            9  ...         0          0              2
# 4           3            3  ...         0          0              6
#
#    PF_FILING_REQ_CD  ACCT_PD  ASSET_AMT  INCOME_AMT  REVENUE_AMT  NTEE_CD  \
# 0                 0        6        0.0         0.0          0.0      NaN
# 1                 0        6        NaN         NaN          NaN      S20
# 2                 0       12        NaN         NaN          NaN      NaN
# 3                 0        6        0.0         0.0          0.0      NaN
# 4                 0       12        NaN         NaN          NaN      X20
#
#                 SORT_NAME
# 0  VOAKY HOPEFUL ROAD INC
# 1                     NaN
# 2                     NaN
# 3              93 STRAITS
# 4                     NaN
#
# [5 rows x 28 columns]
# Sample rows from df3:
#        EIN                                          NAME  ICO  \
# 0   260049                        CORINTH BAPTIST CHURCH  NaN
# 1   360268                              IGLESIA VICTORIA  NaN
# 2   490336                       EASTSIDE BAPTIST CHURCH  NaN
# 3  2296179  RELIGIOUS SCIENCE CHURCH CENTER OF SAN DIEGO  NaN
# 4  3140260                        PILGRIM BAPTIST CHURCH  NaN
#
#                  STREET         CITY STATE         ZIP  GROUP  SUBSECTION  \
# 0             PO BOX 92      HOSFORD    FL  32334-0092   2024           3
# 1  1445 N BOONVILLE AVE  SPRINGFIELD    MO  65802-1894   1678           3
# 2            PO BOX 296      LABELLE    FL  33975-0296   2024           3
# 3      4102 MARLBOROUGH    SAN DIEGO    CA  92105-1462      0           3
# 4        217 N GRANT ST    SAN MATEO    CA  94401-1833   3125           3
#
#    AFFILIATION  ...  ASSET_CD  INCOME_CD  FILING_REQ_CD  PF_FILING_REQ_CD  \
# 0            9  ...         0          0              6                 0
# 1            9  ...         0          0              6                 0
# 2            9  ...         0          0              6                 0
# 3            3  ...         0          0              6                 0
# 4            9  ...         0          0              6                 0
#
#    ACCT_PD  ASSET_AMT  INCOME_AMT  REVENUE_AMT  NTEE_CD  SORT_NAME
# 0       12        NaN         NaN          NaN      NaN        NaN
# 1       12        NaN         NaN          NaN      NaN        NaN
# 2       12        NaN         NaN          NaN      NaN        NaN
# 3        3        NaN         NaN          NaN      NaN        NaN
# 4       12        NaN         NaN          NaN      NaN       1910
#
# [5 rows x 28 columns]
# Sample rows from df4:
#         EIN                                        NAME  \
# 0  10456167                             CHRYSALIS PLACE
# 1  10674605  IGLESIA FUENTE DE AGUA VIVA ORLANDO FL INC
# 2  10674736              US-JAPAN RELATIONSHIP FUND INC
# 3  10709908                          HOGARES AMPARO INC
# 4  10728628                           INTERSECTIONS INC
#
#                       ICO                      STREET       CITY STATE  \
# 0                     NaN           GARDINER ME 04345   AKROTIRI   NaN
# 1        % RODOLFO O FONT                 PO BOX 3869   CAROLINA    PR
# 2       % TATSUHIKO WAKAO  KAWASAKI KANAGAWA 216-0033      JAPAN   NaN
# 3  % CARMEN M CRUZ RIVERA    800 HIOODROMO ST STE 105   SAN JUAN    PR
# 4                     NaN                 PO BOX 1715  PAGO PAGO    AS
#
#           ZIP  GROUP  SUBSECTION  AFFILIATION  ...  ASSET_CD  INCOME_CD  \
# 0  00000-0000      0           3            3  ...         0          0
# 1  00984-3869      0           3            3  ...         0          0
# 2  00000-0000      0           3            3  ...         1          1
# 3  00909-0000      0           3            3  ...         2          2
# 4  96799-1715      0           3            3  ...         0          0
#
#    FILING_REQ_CD  PF_FILING_REQ_CD  ACCT_PD  ASSET_AMT  INCOME_AMT  \
# 0              2                 0       12        0.0         0.0
# 1              6                 0       12        NaN         NaN
# 2              2                 0       12     5434.0        10.0
# 3              0                 1        6    20470.0     20509.0
# 4              2                 0       12        0.0         0.0
#
#    REVENUE_AMT  NTEE_CD  SORT_NAME
# 0          0.0      NaN        NaN
# 1          NaN      X20        NaN
# 2         10.0      Q20        NaN
# 3          NaN      P43        NaN
# 4          0.0      O50        NaN
#
# [5 rows x 28 columns]

# %%
df.head()
# Out:
#       EIN                                              NAME  ICO  \
# 0   19818                      PALMER SECOND BAPTIST CHURCH  NaN
# 1   29215                               ST GEORGE CATHEDRAL  NaN
# 2  587764                              IGLESIA BETHESDA INC  NaN
# 3  635913  MINISTERIO APOSTOLICO JESUCRISTO ES EL SENOR INC  NaN
# 4  765634                        MERCY CHAPEL INTERNATIONAL  NaN
#
#                          STREET          CITY STATE         ZIP  GROUP  \
# 0             1050 THORNDIKE ST        PALMER    MA  01069-1507   3125
# 1                523 E BROADWAY  SOUTH BOSTON    MA  02127-4415   2365
# 2                157 ANDOVER ST        LOWELL    MA  01852-2348      0
# 3                  454 ESSEX ST      LAWRENCE    MA  01840-1242      0
# 4  75 MORTON VILLAGE DR APT 408      MATTAPAN    MA  02126-2433      0
#
#    SUBSECTION  AFFILIATION  ...  ASSET_CD  INCOME_CD  FILING_REQ_CD  \
# 0           3            9  ...         0          0              6
# 1           3            9  ...         0          0              6
# 2           3            3  ...         0          0              6
# 3           3            3  ...         0          0              6
# 4           3            3  ...         0          0              6
#
#    PF_FILING_REQ_CD  ACCT_PD  ASSET_AMT  INCOME_AMT  REVENUE_AMT  NTEE_CD  \
# 0                 0       12        NaN         NaN          NaN      NaN
# 1                 0       12        NaN         NaN          NaN      NaN
# 2                 0       12        NaN         NaN          NaN      X21
# 3                 0       12        NaN         NaN          NaN      X21
# 4                 0       12        NaN         NaN          NaN      X20
#
#    SORT_NAME
# 0       3514
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 28 columns]

# %%
len(df)
# Out:
# 1635278

# %%
len(df1)
# Out:
# 240579

# %%
unique_states = df_combined["STATE"].unique()
print(unique_states)
# Out:
# ['PR' nan 'AS' 'VI' 'AE' 'AP' 'AA' 'GU' 'MH' 'MP' 'FM' 'PW' 'MA' 'NY' 'NJ'
#  'ME' 'NH' 'VT' 'CT' 'RI' 'KY' 'VA' 'IN' 'MI' 'MD' 'DC' 'PA' 'SC' 'OH'
#  'WI' 'ND' 'NC' 'IL' 'MN' 'DE' 'WV' 'IA' 'SD' 'NE' 'FL' 'MO' 'CA' 'TX'
#  'CO' 'TN' 'AR' 'KS' 'GA' 'AL' 'AZ' 'UT' 'WA' 'OK' 'HI' 'LA' 'NV' 'MS'
#  'ID' 'AK' 'NM' 'MT' 'OR' 'WY']

# %%
df.STATE.value_counts().head(10)
# Out:
# CA    168451
# TX    114678
# NY    105527
# FL     85977
# PA     69764
# IL     67326
# OH     66916
# NC     49255
# MI     49142
# GA     46147
# Name: STATE, dtype: int64

# %%
df.STATE.value_counts()
# Out:
# CA    168451
# TX    114678
# NY    105527
# FL     85977
# PA     69764
#        ...
# AS       108
# MH         4
# FM         4
# AA         2
# PW         2
# Name: STATE, Length: 62, dtype: int64

# %%
df.columns
# Out:
# Index(['EIN', 'NAME', 'ICO', 'STREET', 'CITY', 'STATE', 'ZIP', 'GROUP',
#        'SUBSECTION', 'AFFILIATION', 'CLASSIFICATION', 'RULING',
#        'DEDUCTIBILITY', 'FOUNDATION', 'ACTIVITY', 'ORGANIZATION', 'STATUS',
#        'TAX_PERIOD', 'ASSET_CD', 'INCOME_CD', 'FILING_REQ_CD',
#        'PF_FILING_REQ_CD', 'ACCT_PD', 'ASSET_AMT', 'INCOME_AMT', 'REVENUE_AMT',
#        'NTEE_CD', 'SORT_NAME'],
#       dtype='object')

# %%
# Calculate summary statistics for numeric columns
numeric_columns = df_combined.select_dtypes(include=['int64', 'float64']).columns
summary_stats = df_combined[numeric_columns].describe()
print(summary_stats)
# Out:
#                 EIN         GROUP    SUBSECTION   AFFILIATION  CLASSIFICATION  \
# count  1.635278e+06  1.635278e+06  1.635278e+06  1.635278e+06    1.635278e+06
# mean   4.721234e+08  7.523340e+02  4.346013e+00  4.638687e+00    2.276860e+03
# std    2.466882e+08  1.856847e+03  6.323481e+00  2.694518e+00    2.125220e+03
# min    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00    0.000000e+00
# 25%    2.639248e+08  0.000000e+00  3.000000e+00  3.000000e+00    1.000000e+03
# 50%    4.550294e+08  0.000000e+00  3.000000e+00  3.000000e+00    1.000000e+03
# 75%    6.409117e+08  2.390000e+02  3.000000e+00  9.000000e+00    2.000000e+03
# max    9.990094e+08  9.707000e+03  9.200000e+01  9.000000e+00    9.710000e+03
#
#              RULING  DEDUCTIBILITY    FOUNDATION      ACTIVITY  ORGANIZATION  \
# count  1.635278e+06   1.635278e+06  1.635278e+06  1.635278e+06  1.635278e+06
# mean   1.974210e+05   1.138507e+00  1.030713e+01  1.401363e+08  2.069019e+00
# std    1.858521e+04   4.108034e-01  6.392006e+00  2.621931e+08  1.756092e+00
# min    0.000000e+00   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.973040e+05   1.000000e+00  4.000000e+00  0.000000e+00  1.000000e+00
# 50%    1.998120e+05   1.000000e+00  1.500000e+01  0.000000e+00  1.000000e+00
# 75%    2.011090e+05   1.000000e+00  1.500000e+01  1.611801e+08  5.000000e+00
# max    2.017070e+05   4.000000e+00  2.400000e+01  9.990000e+08  6.000000e+00
#
#              STATUS    TAX_PERIOD      ASSET_CD     INCOME_CD  FILING_REQ_CD  \
# count  1.635278e+06  1.300333e+06  1.635278e+06  1.635278e+06   1.635278e+06
# mean   1.061561e+00  2.015748e+05  1.621505e+00  1.570253e+00   2.239843e+00
# std    9.181594e-01  1.005465e+02  2.350207e+00  2.229409e+00   1.897931e+00
# min    1.000000e+00  1.979060e+05  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    1.000000e+00  2.015120e+05  0.000000e+00  0.000000e+00   1.000000e+00
# 50%    1.000000e+00  2.016070e+05  0.000000e+00  0.000000e+00   2.000000e+00
# 75%    1.000000e+00  2.016120e+05  3.000000e+00  3.000000e+00   2.000000e+00
# max    2.500000e+01  2.017070e+05  9.000000e+00  9.000000e+00   8.800000e+01
#
#        PF_FILING_REQ_CD       ACCT_PD     ASSET_AMT    INCOME_AMT  \
# count      1.635278e+06  1.635278e+06  1.282994e+06  1.282994e+06
# mean       7.071152e-02  1.000052e+01  5.080010e+06  3.156928e+06
# std        2.591681e-01  2.967373e+00  2.916971e+08  1.835944e+08
# min        0.000000e+00  0.000000e+00  0.000000e+00 -3.799674e+07
# 25%        0.000000e+00  7.000000e+00  0.000000e+00  0.000000e+00
# 50%        0.000000e+00  1.200000e+01  0.000000e+00  0.000000e+00
# 75%        0.000000e+00  1.200000e+01  1.938690e+05  1.527080e+05
# max        8.000000e+00  1.200000e+01  2.500000e+11  8.533663e+10
#
#         REVENUE_AMT
# count  1.175724e+06
# mean   2.151550e+06
# std    7.563173e+07
# min   -7.906811e+07
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    1.089342e+05
# max    4.846638e+10

# %%
# Print unique values and their counts for categorical columns
categorical_columns = df_combined.select_dtypes(include=['object']).columns
for column in categorical_columns:
    unique_values = df_combined[column].unique()
    value_counts = df_combined[column].value_counts()
    print(f"Column: {column}")
    print("Unique Values:")
    print(unique_values)
    print("Value Counts:")
    print(value_counts)
    print()
# Out:
# Column: NAME
# Unique Values:
# ['IGLESIA FUENTE DE AGUA VIVA ORLANDO FL INC' 'HOGARES AMPARO INC'
#  'PATHSTONE CORPORATION' ... 'UNOYO KOJIMA TRUST'
#  'TOYO SAKUMOTO CHARITABLE TR' 'HAWAII FOUNDATION FOR THE BLIND']
# Value Counts:
# TOASTMASTERS INTERNATIONAL                  9839
# KNIGHTS OF COLUMBUS                         8310
# INTERNATIONAL ASSOCIATION OF LIONS CLUBS    8139
# PEO SISTERHOOD INTERNATIONAL CHAPTER        6305
# ROTARY INTERNATIONAL                        6006
#                                             ...
# PRICE ELECTRIC COOPERATIVE INC                 1
# PORTAGE CHAMBER OF COMMERCE                    1
# POLK-BURNETT ELECTRIC COOPERATIVE              1
# PIERCE-PEPIN COOPERATIVE SERVICES              1
# HAWAII FOUNDATION FOR THE BLIND                1
# Name: NAME, Length: 1234442, dtype: int64
#
# Column: ICO
# Unique Values:
# ['% RODOLFO O FONT' '% CARMEN M CRUZ RIVERA' nan ... '% IRIS TAMAGUSUKU'
#  '% RACHEL CARTWRIGHT' '% HAWAII STATE ASSOCIATION OF LETTE']
# Value Counts:
# % PEO TREASURER                        5806
# % TREASURER                            4404
# % ELLEN M LINTAL                       2091
# % CHIEF FINANCIAL OFFICER              1505
# % PRESIDENT                            1415
#                                        ...
# % DALE ACHENBACH                          1
# % LOUIS HADY                              1
# % JON PEIK                                1
# % ROBERT HILLNER                          1
# % HAWAII STATE ASSOCIATION OF LETTE       1
# Name: ICO, Length: 871540, dtype: int64
#
# Column: STREET
# Unique Values:
# ['PO BOX 3869' '800 HIOODROMO ST STE 105' '1122 CALLE 5' ...
#  '4558 MALIA ST' '100 KAWEHI PL' '4945 CORAL WAY']
# Value Counts:
# 3700 GRAND AVE       6355
# 1 WATERFOWL WAY      4548
# PO BOX 1802          2415
# 770 AUGUSTA RD       2338
# PO BOX 185           1592
#                      ...
# 514 MAJOR AVE           1
# 5360 134TH AVE NW       1
# 248 SARGENT AVE E       1
# 715 14TH AVE            1
# 4945 CORAL WAY          1
# Name: STREET, Length: 1045244, dtype: int64
#
# Column: CITY
# Unique Values:
# ['CAROLINA' 'SAN JUAN' 'SAN ANTONIO' ... 'PAPAALOA' 'KAILU' 'WAIHIAWA']
# Value Counts:
# NEW YORK         20477
# CHICAGO          16653
# WASHINGTON       14667
# HOUSTON          12931
# BROOKLYN         12575
#                  ...
# NEWALD               1
# TARAWA TER           1
# MOUNT SHERMAN        1
# CHARM                1
# WAIHIAWA             1
# Name: CITY, Length: 24585, dtype: int64
#
# Column: STATE
# Unique Values:
# ['PR' nan 'AS' 'VI' 'AE' 'AP' 'AA' 'GU' 'MH' 'MP' 'FM' 'PW' 'MA' 'NY' 'NJ'
#  'ME' 'NH' 'VT' 'CT' 'RI' 'KY' 'VA' 'IN' 'MI' 'MD' 'DC' 'PA' 'SC' 'OH'
#  'WI' 'ND' 'NC' 'IL' 'MN' 'DE' 'WV' 'IA' 'SD' 'NE' 'FL' 'MO' 'CA' 'TX'
#  'CO' 'TN' 'AR' 'KS' 'GA' 'AL' 'AZ' 'UT' 'WA' 'OK' 'HI' 'LA' 'NV' 'MS'
#  'ID' 'AK' 'NM' 'MT' 'OR' 'WY']
# Value Counts:
# CA    168451
# TX    114678
# NY    105527
# FL     85977
# PA     69764
#        ...
# AS       108
# FM         4
# MH         4
# PW         2
# AA         2
# Name: STATE, Length: 62, dtype: int64
#
# Column: ZIP
# Unique Values:
# ['00984-3869' '00909-0000' '00927-5131' ... '93035-1902' '95015-0076'
#  '96825-0854']
# Value Counts:
# 50312-2806    6354
# 38120-2350    4371
# 00000-0000    2420
# 02901-1802    2376
# 29824-1573    2337
#               ...
# 42001-6120       1
# 49098-8304       1
# 46055-9370       1
# 40601-3772       1
# 96825-0854       1
# Name: ZIP, Length: 1232431, dtype: int64
#
# Column: NTEE_CD
# Unique Values:
# ['X20' 'P43' nan ... 'W50C' 'N5XI' 'Y119']
# Value Counts:
# X20     54352
# X21     36262
# P20     29806
# T20     21108
# B82     19806
#         ...
# B70O        1
# N52N        1
# B51F        1
# U53C        1
# Y119        1
# Name: NTEE_CD, Length: 5632, dtype: int64
#
# Column: SORT_NAME
# Unique Values:
# [nan 'PARQUE PLATINO INC' 'PONCE' ... 'CARTWRIGHT RACHAEL'
#  'PACIFIC CENTURY TR TTEE' '145 PHILOTESIAN REBEKAH LODGE']
# Value Counts:
# GROUP RETURN                          540
# PENTECOSTAL HOLINESS CHURCH           335
# INTERNATIONAL PENTECOSTAL HOLINESS    196
# BAPTIST CONVENTION OF NEW MEXICO      183
# SAME                                  106
#                                      ...
# TOWN & COUNTRY RIDERS                   1
# WOMENS INFORMATIN SERVICE               1
# MPRO                                    1
# 6380 DISTRICT                           1
# 145 PHILOTESIAN REBEKAH LODGE           1
# Name: SORT_NAME, Length: 389522, dtype: int64

# %% [markdown]
# ## Visualize
#
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a horizontal bar chart of the top N organizations by income amount

# Set the number of top organizations to consider
top_n = 10

# Sort the organizations by income amount (e.g., eo2 dataframe)
top_organizations = eo2.nlargest(top_n, 'INCOME_AMT')

# Set the figure size
plt.figure(figsize=(10, 6))

# Create the horizontal bar chart
plt.barh(top_organizations['NAME'], top_organizations['INCOME_AMT'])

# Set the title and labels
plt.title(f'Top {top_n} Organizations by Income Amount')
plt.xlabel('Income Amount')
plt.ylabel('Organization')

# Show the plot
plt.show()

# %%
# Create a pie chart of the distribution of affiliations

# Extract the affiliation column from one of the dataframes (e.g., eo1)
affiliation_counts = eo1['AFFILIATION'].value_counts()

# Set the figure size
plt.figure(figsize=(8, 8))

# Create the pie chart
affiliation_counts.plot(kind='pie', autopct='%1.1f%%')

# Set the title and labels
plt.title('Distribution of Affiliations')
plt.ylabel('')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='STATE', data=df, order=df['STATE'].value_counts().head(10).index)
plt.title('Distribution of States')
plt.xlabel('State')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Summarize Your Results
#
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset?
#
# There are 1,234,442 unique organization names in the dataset.
# The most common organization name is "TOASTMASTERS INTERNATIONAL" with 9,839 occurrences.
#
# There are 871,540 unique "In Care of Name" values in the dataset.
# The most common "In Care of Name" value is "% PEO TREASURER" with 5,806 occurrences.
#
# There are 1,045,244 unique street addresses in the dataset.
# The most common street address is "3700 GRAND AVE" with 6,355 occurrences.
#
# There are 24,585 unique city names in the dataset.
# The most common city name is "NEW YORK" with 20,477 occurrences.
#
# There are 62 unique state codes in the dataset.
# The most common state code is "CA" (California) with 168,451 occurrences.
#
# There are 1,232,431 unique ZIP codes in the dataset.
# The most common ZIP code is "50312-2806" with 6,354 occurrences.
#
# There are 5,632 unique NTEE codes in the dataset.
# The most common NTEE code is "X20" with 54,352 occurrences.
#
# 2. Do you have any concerns about your dataset?
#
# ICO: This column has a significant number of missing values (545,140 out of 1,635,278 entries), which may reduce its usefulness for analysis.
#
# TAX_PERIOD: This column also has a considerable number of missing values (305,945 out of 1,635,278 entries).
#
# ASSET_AMT, INCOME_AMT, and REVENUE_AMT: These columns have a substantial number of missing values (approximately 506,284, 506,284, and 517,554 missing values, respectively), which may limit their utility in analysis.
#
# NTEE_CD and SORT_NAME: These columns have a large number of missing values (approximately 658,381 and 1,197,362 missing values, respectively). Depending on the analysis objectives, I may consider dropping these columns if they are not crucial for the analysis.
#
#
# 3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?
# Identify and handle any outliers that could skew the analysis.
# Evaluate the quality and consistency of the data, looking for potential errors or inconsistencies.
